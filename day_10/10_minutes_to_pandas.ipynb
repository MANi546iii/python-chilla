# %% [markdown]
# Topic : Pandas (python cheat sheet practice)10 min to pandas\
# Written by : Abdul Rehman\
# Date: 27.08.2025\
# Email: oyeeemani47@gmail.com

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1- object creation

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=25)

dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12',
#                '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16',
#                '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20',
#                '2013-01-21', '2013-01-22', '2013-01-23', '2013-01-24',
#                '2013-01-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range("20130101", periods=25)
df = pd.DataFrame(np.random.randn(25, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.305342 -2.021788 -0.349637  0.378864
# 2013-01-02 -0.348514 -0.739193  0.321989 -0.372955
# 2013-01-03  0.169581 -0.955842 -0.942593  0.632671
# 2013-01-04 -1.259259 -0.811746  2.472324  0.980616
# 2013-01-05  1.055122 -2.312411  0.572482 -0.942814
# 2013-01-06  0.816194 -1.759098  0.152998 -0.619544
# 2013-01-07 -0.670401 -0.783784 -1.136981 -0.842396
# 2013-01-08  0.245872  1.233770  0.739149  0.287205
# 2013-01-09  0.160581 -1.050100  2.163645  0.045224
# 2013-01-10 -0.121067 -0.911128  0.506972 -0.277538
# 2013-01-11  0.123367 -1.028279  1.409142  0.245328
# 2013-01-12  0.658112  0.525922  0.071993 -0.039960
# 2013-01-13 -0.377825 -0.110442 -0.333305  0.027407
# 2013-01-14  0.996721 -1.231255  1.717342 -0.690120
# 2013-01-15 -0.657109 -1.154005 -0.462927  2.106963
# 2013-01-16  0.401525  1.223879  0.014806 -1.087672
# 2013-01-17 -0.520763 -0.274451  1.537935  1.684936
# ...

# %%
# dictionary
dict={'ammar':6.0,'farhan':5.5}

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 25 entries, 2013-01-01 to 2013-01-25
# Freq: D
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       25 non-null     float64
#  1   B       25 non-null     float64
#  2   C       25 non-null     float64
#  3   D       25 non-null     float64
# dtypes: float64(4)
# memory usage: 1000.0 bytes

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12',
#                '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16',
#                '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20',
#                '2013-01-21', '2013-01-22', '2013-01-23', '2013-01-24',
#                '2013-01-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-0.30534182, -2.02178788, -0.34963693,  0.37886447],
#        [-0.34851405, -0.73919302,  0.32198943, -0.37295462],
#        [ 0.16958074, -0.95584215, -0.9425933 ,  0.63267057],
#        [-1.25925876, -0.81174641,  2.47232387,  0.98061553],
#        [ 1.05512207, -2.31241141,  0.57248242, -0.94281438],
#        [ 0.8161941 , -1.75909831,  0.15299787, -0.61954364],
#        [-0.67040114, -0.7837841 , -1.13698052, -0.84239637],
#        [ 0.24587205,  1.23377016,  0.73914933,  0.28720464],
#        [ 0.16058095, -1.05009957,  2.16364546,  0.04522443],
#        [-0.12106699, -0.91112809,  0.50697175, -0.27753818],
#        [ 0.12336664, -1.02827855,  1.40914177,  0.24532815],
#        [ 0.6581119 ,  0.52592184,  0.07199285, -0.03995957],
#        [-0.37782518, -0.11044243, -0.33330542,  0.0274072 ],
#        [ 0.99672113, -1.23125483,  1.7173416 , -0.69011991],
#        [-0.65710911, -1.15400488, -0.46292744,  2.10696307],
# ...

# %%
df.iloc[0:7,0:3] #index ko lock krne ke liye
# Out:
#                    A         B         C
# 2013-01-01 -0.305342 -2.021788 -0.349637
# 2013-01-02 -0.348514 -0.739193  0.321989
# 2013-01-03  0.169581 -0.955842 -0.942593
# 2013-01-04 -1.259259 -0.811746  2.472324
# 2013-01-05  1.055122 -2.312411  0.572482
# 2013-01-06  0.816194 -1.759098  0.152998
# 2013-01-07 -0.670401 -0.783784 -1.136981

# %%
df.loc[:,['A','B']] # loc
# Out:
#                    A         B
# 2013-01-01 -0.305342 -2.021788
# 2013-01-02 -0.348514 -0.739193
# 2013-01-03  0.169581 -0.955842
# 2013-01-04 -1.259259 -0.811746
# 2013-01-05  1.055122 -2.312411
# 2013-01-06  0.816194 -1.759098
# 2013-01-07 -0.670401 -0.783784
# 2013-01-08  0.245872  1.233770
# 2013-01-09  0.160581 -1.050100
# 2013-01-10 -0.121067 -0.911128
# 2013-01-11  0.123367 -1.028279
# 2013-01-12  0.658112  0.525922
# 2013-01-13 -0.377825 -0.110442
# 2013-01-14  0.996721 -1.231255
# 2013-01-15 -0.657109 -1.154005
# 2013-01-16  0.401525  1.223879
# 2013-01-17 -0.520763 -0.274451
# 2013-01-18 -0.198512 -0.204817
# 2013-01-19 -0.395036 -0.865970
# 2013-01-20 -0.430458 -2.124172
# 2013-01-21  0.093704  1.179260
# 2013-01-22  0.965239  0.513913
# 2013-01-23  1.029629  0.646839
# 2013-01-24  0.499268  0.194364
# 2013-01-25  0.849589 -1.833295

# %%
df.iloc[3]
# Out:
# A   -1.259259
# B   -0.811746
# C    2.472324
# D    0.980616
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
import seaborn as sns  
kashti = sns.load_dataset('titanic')

# %%
kashti.sample(100)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 105         0       3    male  28.0      0      0   7.8958        S   Third
# 355         0       3    male  28.0      0      0   9.5000        S   Third
# 839         1       1    male   NaN      0      0  29.7000        C   First
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# 342         0       2    male  28.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 45          0       3    male   NaN      0      0   8.0500        S   Third
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 96          0       1    male  71.0      0      0  34.6542        C   First
# 95          0       3    male   NaN      0      0   8.0500        S   Third
# 447         1       1    male  34.0      0      0  26.5500        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti[kashti['age']> 60]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 33          0       2    male  66.0      0      0   10.5000        S  Second
# 54          0       1    male  65.0      0      1   61.9792        C   First
# 96          0       1    male  71.0      0      0   34.6542        C   First
# 116         0       3    male  70.5      0      0    7.7500        Q   Third
# 170         0       1    male  61.0      0      0   33.5000        S   First
# 252         0       1    male  62.0      0      0   26.5500        S   First
# 275         1       1  female  63.0      1      0   77.9583        S   First
# 280         0       3    male  65.0      0      0    7.7500        Q   Third
# 326         0       3    male  61.0      0      0    6.2375        S   Third
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 456         0       1    male  65.0      0      0   26.5500        S   First
# ...

# %%
kashti[kashti['fare']==0]
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 179         0       3  male  36.0      0      0   0.0        S   Third  man
# 263         0       1  male  40.0      0      0   0.0        S   First  man
# 271         1       3  male  25.0      0      0   0.0        S   Third  man
# 277         0       2  male   NaN      0      0   0.0        S  Second  man
# 302         0       3  male  19.0      0      0   0.0        S   Third  man
# 413         0       2  male   NaN      0      0   0.0        S  Second  man
# 466         0       2  male   NaN      0      0   0.0        S  Second  man
# 481         0       2  male   NaN      0      0   0.0        S  Second  man
# 597         0       3  male  49.0      0      0   0.0        S   Third  man
# 633         0       1  male   NaN      0      0   0.0        S   First  man
# 674         0       2  male   NaN      0      0   0.0        S  Second  man
# ...
